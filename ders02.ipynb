# %% [markdown]
# <a href="https://colab.research.google.com/github/yusufsahin/python-training-maro/blob/main/ders02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print("CWD:",os.getcwd())
print("content:",os.listdir("/content")[:10])
# Out:
# CWD: /content
# content: ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-451384764.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
path="/content/notes.txt"
with open(path,"w",encoding="utf-8") as f:
  f.write("hello colab!")
  f.write("hello python!")

# %%
with open(path,"r",encoding="utf-8") as f:
  content=f.read()
print(content)
# Out:
# hello colab!hello python!
# hello google!
# hello file!

# %%
with open(path,"a",encoding="utf-8") as f:
  f.write("\nhello google!")
  f.write("\nhello file!")

# %%
with open(path, "r", encoding="utf-8") as f:
    for line in f:
        print("LINE:", line.rstrip())
# Out:
# LINE: hello colab!hello python!
# LINE: hello google!
# LINE: hello file!

# %%
from pathlib import Path
base=Path("/content/data")
base.mkdir(parents=True,exist_ok=True)
file_path=base/"example.txt"
file_path.write_text("Merhaba pathlib\n",encoding="utf-8")
print(file_path.read_text(encoding="utf-8"))
# Out:
# Merhaba pathlib
