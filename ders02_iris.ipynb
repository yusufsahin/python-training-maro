# %% [markdown]
# <a href="https://colab.research.google.com/github/yusufsahin/python-training-maro/blob/main/ders02_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
out="/content/iris_dataset.csv"

with requests.get(url,stream=True,timeout=60) as r:
  r.raise_for_status()
  with open(out,"wb") as f:
    for chunk in r.iter_content(chunk_size=1024 * 1024):
      if chunk:
        f.write(chunk)
  print("Yazıldı:",out)
# Out:
# Yazıldı: /content/iris_dataset.csv

# %%
with open(out, "r", encoding="utf-8") as f:
    for i in range(6):          # header + 5 satır
        print(f.readline().rstrip())
# Out:
# sepal_length,sepal_width,petal_length,petal_width,species
# 5.1,3.5,1.4,0.2,setosa
# 4.9,3.0,1.4,0.2,setosa
# 4.7,3.2,1.3,0.2,setosa
# 4.6,3.1,1.5,0.2,setosa
# 5.0,3.6,1.4,0.2,setosa

# %% [markdown]
# Daha Temiz kod yazmak için foksiyonlara file işlemleri bölünebilir

# %%
from pathlib import Path

def write_text(path: str | Path, text: str, *, append: bool = False) -> None:
    path = Path(path)
    mode = "a" if append else "w"
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, mode, encoding="utf-8") as f:
        f.write(text)
def read_text(path: str | Path) -> str:
    path = Path(path)
    with open(path, "r", encoding="utf-8") as f:
        return f.read()
write_text("/content/out/hello.txt", "Selam!\n")
write_text("/content/out/hello.txt", "Ek satır\n", append=True)
print(read_text("/content/out/hello.txt"))
# Out:
# Selam!
# Ek satır
